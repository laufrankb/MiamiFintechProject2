# %% [markdown]
# # Initial Imports

# %%
import pandas as pd
import numpy as np
from get_lyric_data import get_lyrics
from get_chart_data import get_chart_genre

import matplotlib as plt
pd.options.plotting.backend = 'hvplot'

# %% [markdown]
# # Lyric Data

# %% [markdown]
# ### Search for top songs in GENRE

# %%
# Use 'Track details' endpoint to retrieve lyrics for a single track

# GENRE CODES
# POP,HIP_HOP_RAP,DANCE,ELECTRONIC,SOUL_RNB,ALTERNATIVE,ROCK,LATIN,FILM_TV,COUNTRY,
# AFRO_BEATS,WORLDWIDE,REGGAE_DANCE_HALL,HOUSE,K_POP,FRENCH_POP,SINGER_SONGWRITER,REG_MEXICO


genre = 'COUNTRY'
limit_songs = 50

querystring = {"genre_code": genre,"limit":limit_songs}
chart_response = get_chart_genre(querystring)
chart_response
# Out:
# [{'id': '595243928',
#   'type': 'MUSIC',
#   'layout': '5',
#   'title': 'The Cowboy In Me (Yellowstone Edition)',
#   'url': 'https://www.shazam.com/track/595243928/the-cowboy-in-me-yellowstone-edition',
#   'apple_music_url': 'https://music.apple.com/gb/album/the-cowboy-in-me-yellowstone-edition/1597763898',
#   'subtitle': 'Tim McGraw',
#   'images': {'background': 'https://is4-ssl.mzstatic.com/image/thumb/Features125/v4/91/07/f7/9107f78f-e0f5-a6db-f4d8-ae402ebf38af/pr_source.png/800x800cc.jpg',
#    'coverart': 'https://is1-ssl.mzstatic.com/image/thumb/Music116/v4/62/18/bd/6218bd2c-4c21-8ee8-ab0b-4b62afb13f16/21BMR0003041.rgb.jpg/400x400cc.jpg',
#    'coverarthq': 'https://is1-ssl.mzstatic.com/image/thumb/Music116/v4/62/18/bd/6218bd2c-4c21-8ee8-ab0b-4b62afb13f16/21BMR0003041.rgb.jpg/400x400cc.jpg',
#    'joecolor': 'b:efb182p:070609s:32220dt:352821q:583f24'},
#   'share': {'subject': 'The Cowboy In Me (Yellowstone Edition) - Tim McGraw',
#    'text': 'I used Shazam to discover The Cowboy In Me (Yellowstone Edition) by Tim McGraw.',
#    'href': 'https://www.shazam.com/track/595243928/the-cowboy-in-me-yellowstone-edition',
#    'image': 'https://is1-ssl.mzstatic.com/image/thumb/Music116/v4/62/18/bd/6218bd2c-4c21-8ee8-ab0b-4b62afb13f16/21BMR0003041.rgb.jpg/400x400cc.jpg',
#    'twitter': 'I used @Shazam to discover The Cowboy In Me (Yellowstone Edition) by Tim McGraw.',
#    'html': 'https://www.shazam.com/snippets/email-share/595243928?lang=en&country=GB',
#    'avatar': 'https://is4-ssl.mzstatic.com/image/thumb/Features125/v4/91/07/f7/9107f78f-e0f5-a6db-f4d8-ae402ebf38af/pr_source.png/800x800cc.jpg',
#    'snapchat': 'https://www.shazam.com/partner/sc/track/595243928'},
#   'hub': {'type': 'APPLEMUSIC',
#    'image': 'https://images.shazam.com/static/icons/hub/web/v5/applemusic.png',
#    'actions': [{'name': 'apple', 'type': 'applemusicplay', 'id': '1597763900'},
#     {'name': 'apple',
#      'type': 'uri',
#      'uri': 'https://audio-ssl.itunes.apple.com/itunes-assets/AudioPreview116/v4/f3/64/64/f36464c5-f717-5842-57dd-9401d86077a6/mzaf_3426175162411399949.plus.aac.ep.m4a'}],
#    'options': [{'caption': 'OPEN',
#      'actions': [{'name': 'hub:applemusic:deeplink',
#        'type': 'applemusicopen',
#        'uri': 'https://music.apple.com/gb/album/the-cowboy-in-me-yellowstone-edition/1597763898?i=1597763900&mttnagencyid=s2n&mttnsiteid=125115&mttn3pid=Apple-Shazam&mttnsub1=Shazam_web&mttnsub2=5348615A-616D-3235-3830-44754D6D5973&itscg=30201&app=music&itsct=Shazam_web'},
#       {'name': 'hub:applemusic:deeplink',
#        'type': 'uri',
#        'uri': 'https://music.apple.com/gb/album/the-cowboy-in-me-yellowstone-edition/1597763898?i=1597763900&mttnagencyid=s2n&mttnsiteid=125115&mttn3pid=Apple-Shazam&mttnsub1=Shazam_web&mttnsub2=5348615A-616D-3235-3830-44754D6D5973&itscg=30201&app=music&itsct=Shazam_web'}],
#      'beacondata': {'type': 'open', 'providername': 'applemusic'},
#      'image': 'https://images.shazam.com/static/icons/hub/web/v5/overflow-open-option.png',
#      'type': 'open',
#      'listcaption': 'Open in Apple Music',
#      'overflowimage': 'https://images.shazam.com/static/icons/hub/web/v5/applemusic-overflow.png',
#      'colouroverflowimage': False,
#      'providername': 'applemusic'}],
#    'explicit': False,
#    'displayname': 'APPLE MUSIC'},
#   'artists': [{'follow': {'followkey': 'A_5609'},
#     'alias': 'tim-mcgraw',
#     'id': '5609',
#     'adamid': '3496236'}]},
#  {'id': '54640449',
#   'type': 'MUSIC',
#   'layout': '5',
#   'title': 'Jingle Bell Rock',
#   'url': 'https://www.shazam.com/track/54640449/jingle-bell-rock',
#   'apple_music_url': 'https://music.apple.com/gb/album/jingle-bell-rock/296632417',
#   'subtitle': 'Bobby Helms',
#   'images': {'background': 'https://is4-ssl.mzstatic.com/image/thumb/Features114/v4/67/a9/26/67a9263e-245a-f8de-5d04-33e9a3eec641/pr_source.png/800x800cc.jpg',
#    'coverart': 'https://is4-ssl.mzstatic.com/image/thumb/Music/67/c4/4d/mzi.bttyjdcq.tif/400x400cc.jpg',
#    'coverarthq': 'https://is4-ssl.mzstatic.com/image/thumb/Music/67/c4/4d/mzi.bttyjdcq.tif/400x400cc.jpg',
#    'joecolor': 'b:2d1415p:fffaaas:f6efc4t:d4cc8cq:cec3a1'},
#   'share': {'subject': 'Jingle Bell Rock - Bobby Helms',
#    'text': 'I used Shazam to discover Jingle Bell Rock by Bobby Helms.',
#    'href': 'https://www.shazam.com/track/54640449/jingle-bell-rock',
#    'image': 'https://is4-ssl.mzstatic.com/image/thumb/Music/67/c4/4d/mzi.bttyjdcq.tif/400x400cc.jpg',
#    'twitter': 'I used @Shazam to discover Jingle Bell Rock by Bobby Helms.',
#    'html': 'https://www.shazam.com/snippets/email-share/54640449?lang=en&country=GB',
#    'avatar': 'https://is4-ssl.mzstatic.com/image/thumb/Features114/v4/67/a9/26/67a9263e-245a-f8de-5d04-33e9a3eec641/pr_source.png/800x800cc.jpg',
#    'snapchat': 'https://www.shazam.com/partner/sc/track/54640449'},
#   'hub': {'type': 'APPLEMUSIC',
#    'image': 'https://images.shazam.com/static/icons/hub/web/v5/applemusic.png',
#    'actions': [{'name': 'apple', 'type': 'applemusicplay', 'id': '296632441'},
#     {'name': 'apple',
#      'type': 'uri',
#      'uri': 'https://audio-ssl.itunes.apple.com/itunes-assets/AudioPreview115/v4/93/08/2c/93082c6e-be48-5403-1869-1e7408717ece/mzaf_6945262713134350197.plus.aac.p.m4a'}],
#    'options': [{'caption': 'OPEN',
#      'actions': [{'name': 'hub:applemusic:deeplink',
#        'type': 'applemusicopen',
#        'uri': 'https://music.apple.com/gb/album/jingle-bell-rock/296632417?i=296632441&mttnagencyid=s2n&mttnsiteid=125115&mttn3pid=Apple-Shazam&mttnsub1=Shazam_web&mttnsub2=5348615A-616D-3235-3830-44754D6D5973&itscg=30201&app=music&itsct=Shazam_web'},
#       {'name': 'hub:applemusic:deeplink',
#        'type': 'uri',
#        'uri': 'https://music.apple.com/gb/album/jingle-bell-rock/296632417?i=296632441&mttnagencyid=s2n&mttnsiteid=125115&mttn3pid=Apple-Shazam&mttnsub1=Shazam_web&mttnsub2=5348615A-616D-3235-3830-44754D6D5973&itscg=30201&app=music&itsct=Shazam_web'}],
#      'beacondata': {'type': 'open', 'providername': 'applemusic'},
#      'image': 'https://images.shazam.com/static/icons/hub/web/v5/overflow-open-option.png',
#      'type': 'open',
#      'listcaption': 'Open in Apple Music',
#      'overflowimage': 'https://images.shazam.com/static/icons/hub/web/v5/applemusic-overflow.png',
#      'colouroverflowimage': False,
#      'providername': 'applemusic'}],
#    'explicit': False,
#    'displayname': 'APPLE MUSIC'},
#   'artists': [{'follow': {'followkey': 'A_468244'},
#     'alias': 'bobby-helms',
#     'id': '468244',
#     'adamid': '1579400'}]},
#  {'id': '568180108',
#   'type': 'MUSIC',
#   'layout': '5',
#   'title': 'Fancy Like',
#   'url': 'https://www.shazam.com/track/568180108/fancy-like',
#   'apple_music_url': 'https://music.apple.com/gb/album/fancy-like/1595927679',
#   'subtitle': 'Walker Hayes',
#   'images': {'background': 'https://is5-ssl.mzstatic.com/image/thumb/Music125/v4/21/42/4d/21424d42-8255-d95a-eca4-bfceb6c2850c/pr_source.png/800x800cc.jpg',
#    'coverart': 'https://is2-ssl.mzstatic.com/image/thumb/Music126/v4/7d/66/4c/7d664ceb-ae82-0645-4996-daf2f543e7b3/886449714209.jpg/400x400cc.jpg',
#    'coverarthq': 'https://is2-ssl.mzstatic.com/image/thumb/Music126/v4/7d/66/4c/7d664ceb-ae82-0645-4996-daf2f543e7b3/886449714209.jpg/400x400cc.jpg',
#    'joecolor': 'b:1a2529p:a6ceccs:ec9b61t:8aacabq:c28456'},
#   'share': {'subject': 'Fancy Like - Walker Hayes',
#    'text': 'I used Shazam to discover Fancy Like by Walker Hayes.',
#    'href': 'https://www.shazam.com/track/568180108/fancy-like',
#    'image': 'https://is2-ssl.mzstatic.com/image/thumb/Music126/v4/7d/66/4c/7d664ceb-ae82-0645-4996-daf2f543e7b3/886449714209.jpg/400x400cc.jpg',
#    'twitter': 'I used @Shazam to discover Fancy Like by Walker Hayes.',
#    'html': 'https://www.shazam.com/snippets/email-share/568180108?lang=en&country=GB',
#    'avatar': 'https://is5-ssl.mzstatic.com/image/thumb/Music125/v4/21/42/4d/21424d42-8255-d95a-eca4-bfceb6c2850c/pr_source.png/800x800cc.jpg',
#    'snapchat': 'https://www.shazam.com/partner/sc/track/568180108'},
#   'hub': {'type': 'APPLEMUSIC',
#    'image': 'https://images.shazam.com/static/icons/hub/web/v5/applemusic.png',
#    'actions': [{'name': 'apple', 'type': 'applemusicplay', 'id': '1595928077'},
#     {'name': 'apple',
#      'type': 'uri',
#      'uri': 'https://audio-ssl.itunes.apple.com/itunes-assets/AudioPreview126/v4/dc/73/79/dc7379ed-ffa5-b79a-49f8-15c372e72680/mzaf_8384113679181684065.plus.aac.ep.m4a'}],
#    'options': [{'caption': 'OPEN',
#      'actions': [{'name': 'hub:applemusic:deeplink',
#        'type': 'applemusicopen',
#        'uri': 'https://music.apple.com/gb/album/fancy-like/1595927679?i=1595928077&mttnagencyid=s2n&mttnsiteid=125115&mttn3pid=Apple-Shazam&mttnsub1=Shazam_web&mttnsub2=5348615A-616D-3235-3830-44754D6D5973&itscg=30201&app=music&itsct=Shazam_web'},
#       {'name': 'hub:applemusic:deeplink',
#        'type': 'uri',
#        'uri': 'https://music.apple.com/gb/album/fancy-like/1595927679?i=1595928077&mttnagencyid=s2n&mttnsiteid=125115&mttn3pid=Apple-Shazam&mttnsub1=Shazam_web&mttnsub2=5348615A-616D-3235-3830-44754D6D5973&itscg=30201&app=music&itsct=Shazam_web'}],
#      'beacondata': {'type': 'open', 'providername': 'applemusic'},
#      'image': 'https://images.shazam.com/static/icons/hub/web/v5/overflow-open-option.png',
#      'type': 'open',
#      'listcaption': 'Open in Apple Music',
#      'overflowimage': 'https://images.shazam.com/static/icons/hub/web/v5/applemusic-overflow.png',
#      'colouroverflowimage': False,
#      'providername': 'applemusic'}],
#    'explicit': False,
#    'displayname': 'APPLE MUSIC'},
#   'artists': [{'follow': {'followkey': 'A_40817516'},
#     'alias': 'walker-hayes',
#     'id': '40817516',
#     'adamid': '382876655'}]},
#  {'id': '52815945',
#   'type': 'MUSIC',
#   'layout': '5',
#   'title': 'Enchanted',
#   'url': 'https://www.shazam.com/track/52815945/enchanted',
#   'apple_music_url': 'https://music.apple.com/gb/album/enchanted/1445941811',
#   'subtitle': 'Taylor Swift',
#   'images': {'background': 'https://is5-ssl.mzstatic.com/image/thumb/Music126/v4/38/1b/cb/381bcba1-d356-c116-8169-bd29cbb4cafb/pr_source.png/800x800cc.jpg',
#    'coverart': 'https://is3-ssl.mzstatic.com/image/thumb/Music126/v4/cc/0d/1d/cc0d1d52-87b8-020e-8f89-f5b10cc1add3/18OPBMR00215.rgb.jpg/400x400cc.jpg',
#    'coverarthq': 'https://is3-ssl.mzstatic.com/image/thumb/Music126/v4/cc/0d/1d/cc0d1d52-87b8-020e-8f89-f5b10cc1add3/18OPBMR00215.rgb.jpg/400x400cc.jpg',
#    'joecolor': 'b:1b1b1bp:ffffffs:f3d8bft:d1d1d1q:c8b29e'},
#   'share': {'subject': 'Enchanted - Taylor Swift',
#    'text': 'I used Shazam to discover Enchanted by Taylor Swift.',
#    'href': 'https://www.shazam.com/track/52815945/enchanted',
#    'image': 'https://is3-ssl.mzstatic.com/image/thumb/Music126/v4/cc/0d/1d/cc0d1d52-87b8-020e-8f89-f5b10cc1add3/18OPBMR00215.rgb.jpg/400x400cc.jpg',
#    'twitter': 'I used @Shazam to discover Enchanted by Taylor Swift.',
#    'html': 'https://www.shazam.com/snippets/email-share/52815945?lang=en&country=GB',
#    'avatar': 'https://is5-ssl.mzstatic.com/image/thumb/Music126/v4/38/1b/cb/381bcba1-d356-c116-8169-bd29cbb4cafb/pr_source.png/800x800cc.jpg',
#    'snapchat': 'https://www.shazam.com/partner/sc/track/52815945'},
#   'hub': {'type': 'APPLEMUSIC',
#    'image': 'https://images.shazam.com/static/icons/hub/web/v5/applemusic.png',
#    'actions': [{'name': 'apple', 'type': 'applemusicplay', 'id': '1445942119'},
#     {'name': 'apple',
#      'type': 'uri',
#      'uri': 'https://audio-ssl.itunes.apple.com/itunes-assets/AudioPreview116/v4/77/b8/d5/77b8d566-ccd6-5bcb-ed99-0097f14b7c47/mzaf_630805555506129096.plus.aac.ep.m4a'}],
#    'options': [{'caption': 'OPEN',
#      'actions': [{'name': 'hub:applemusic:deeplink',
#        'type': 'applemusicopen',
#        'uri': 'https://music.apple.com/gb/album/enchanted/1445941811?i=1445942119&mttnagencyid=s2n&mttnsiteid=125115&mttn3pid=Apple-Shazam&mttnsub1=Shazam_web&mttnsub2=5348615A-616D-3235-3830-44754D6D5973&itscg=30201&app=music&itsct=Shazam_web'},
#       {'name': 'hub:applemusic:deeplink',
#        'type': 'uri',
#        'uri': 'https://music.apple.com/gb/album/enchanted/1445941811?i=1445942119&mttnagencyid=s2n&mttnsiteid=125115&mttn3pid=Apple-Shazam&mttnsub1=Shazam_web&mttnsub2=5348615A-616D-3235-3830-44754D6D5973&itscg=30201&app=music&itsct=Shazam_web'}],
#      'beacondata': {'type': 'open', 'providername': 'applemusic'},
#      'image': 'https://images.shazam.com/static/icons/hub/web/v5/overflow-open-option.png',
#      'type': 'open',
#      'listcaption': 'Open in Apple Music',
#      'overflowimage': 'https://images.shazam.com/static/icons/hub/web/v5/applemusic-overflow.png',
#      'colouroverflowimage': False,
#      'providername': 'applemusic'}],
#    'explicit': False,
#    'displayname': 'APPLE MUSIC'},
#   'artists': [{'follow': {'followkey': 'A_40170654'},
#     'alias': 'taylor-swift',
#     'id': '40170654',
#     'adamid': '159260351'}]},
#  {'id': '504707938',
#   'type': 'MUSIC',
#   'layout': '5',
#   'title': 'West Texas In My Eye',
#   'url': 'https://www.shazam.com/track/504707938/west-texas-in-my-eye',
#   'apple_music_url': 'https://music.apple.com/gb/album/west-texas-in-my-eye/1491087118',
#   'subtitle': 'The Panhandlers',
#   'images': {'background': 'https://is5-ssl.mzstatic.com/image/thumb/Music124/v4/e7/84/3a/e7843ada-f71a-e9b0-ac83-4551198f5381/859736199461_cover.jpg/400x400cc.jpg',
#    'coverart': 'https://is5-ssl.mzstatic.com/image/thumb/Music124/v4/e7/84/3a/e7843ada-f71a-e9b0-ac83-4551198f5381/859736199461_cover.jpg/400x400cc.jpg',
#    'coverarthq': 'https://is5-ssl.mzstatic.com/image/thumb/Music124/v4/e7/84/3a/e7843ada-f71a-e9b0-ac83-4551198f5381/859736199461_cover.jpg/400x400cc.jpg',
#    'joecolor': 'b:101916p:d2ddc3s:bfd1b8t:abb5a0q:9cac97'},
#   'share': {'subject': 'West Texas In My Eye - The Panhandlers',
#    'text': 'I used Shazam to discover West Texas In My Eye by The Panhandlers.',
#    'href': 'https://www.shazam.com/track/504707938/west-texas-in-my-eye',
#    'image': 'https://is5-ssl.mzstatic.com/image/thumb/Music124/v4/e7/84/3a/e7843ada-f71a-e9b0-ac83-4551198f5381/859736199461_cover.jpg/400x400cc.jpg',
#    'twitter': 'I used @Shazam to discover West Texas In My Eye by The Panhandlers.',
#    'html': 'https://www.shazam.com/snippets/email-share/504707938?lang=en&country=GB',
#    'snapchat': 'https://www.shazam.com/partner/sc/track/504707938'},
#   'hub': {'type': 'APPLEMUSIC',
#    'image': 'https://images.shazam.com/static/icons/hub/web/v5/applemusic.png',
#    'actions': [{'name': 'apple', 'type': 'applemusicplay', 'id': '1491087516'},
#     {'name': 'apple',
#      'type': 'uri',
#      'uri': 'https://audio-ssl.itunes.apple.com/itunes-assets/AudioPreview125/v4/56/69/70/56697055-73ba-8b85-9488-267ad5bc4a61/mzaf_2851065002580307982.plus.aac.ep.m4a'}],
#    'options': [{'caption': 'OPEN',
#      'actions': [{'name': 'hub:applemusic:deeplink',
#        'type': 'applemusicopen',
#        'uri': 'https://music.apple.com/gb/album/west-texas-in-my-eye/1491087118?i=1491087516&mttnagencyid=s2n&mttnsiteid=125115&mttn3pid=Apple-Shazam&mttnsub1=Shazam_web&mttnsub2=5348615A-616D-3235-3830-44754D6D5973&itscg=30201&app=music&itsct=Shazam_web'},
#       {'name': 'hub:applemusic:deeplink',
#        'type': 'uri',
#        'uri': 'https://music.apple.com/gb/album/west-texas-in-my-eye/1491087118?i=1491087516&mttnagencyid=s2n&mttnsiteid=125115&mttn3pid=Apple-Shazam&mttnsub1=Shazam_web&mttnsub2=5348615A-616D-3235-3830-44754D6D5973&itscg=30201&app=music&itsct=Shazam_web'}],
#      'beacondata': {'type': 'open', 'providername': 'applemusic'},
#      'image': 'https://images.shazam.com/static/icons/hub/web/v5/overflow-open-option.png',
#      'type': 'open',
#      'listcaption': 'Open in Apple Music',
#      'overflowimage': 'https://images.shazam.com/static/icons/hub/web/v5/applemusic-overflow.png',
#      'colouroverflowimage': False,
#      'providername': 'applemusic'}],
#    'explicit': False,
#    'displayname': 'APPLE MUSIC'},
#   'artists': None},
#  {'id': '463807349',
#   'type': 'MUSIC',
#   'layout': '5',
#   'title': 'Old Town Road (Remix)',
#   'url': 'https://www.shazam.com/track/463807349/old-town-road-remix',
#   'apple_music_url': 'https://music.apple.com/gb/album/old-town-road-feat-billy-ray-cyrus-remix/1468166325',
#   'subtitle': 'Lil Nas X Feat. Billy Ray Cyrus',
#   'images': {'background': 'https://is5-ssl.mzstatic.com/image/thumb/Features125/v4/07/89/a3/0789a358-0ee5-6f13-8a54-8dc1a113066a/pr_source.png/800x800cc.jpg',
#    'coverart': 'https://is2-ssl.mzstatic.com/image/thumb/Music124/v4/07/d4/c3/07d4c33e-b793-d78f-bb1b-52f1e224da88/886447788264.jpg/400x400cc.jpg',
#    'coverarthq': 'https://is2-ssl.mzstatic.com/image/thumb/Music124/v4/07/d4/c3/07d4c33e-b793-d78f-bb1b-52f1e224da88/886447788264.jpg/400x400cc.jpg',
#    'joecolor': 'b:131a22p:eef4ecs:d1cacft:c2c8c4q:aba7ac'},
#   'share': {'subject': 'Old Town Road (Remix) - Lil Nas X Feat. Billy Ray Cyrus',
#    'text': 'I used Shazam to discover Old Town Road (Remix) by Lil Nas X Feat. Billy Ray Cyrus.',
#    'href': 'https://www.shazam.com/track/463807349/old-town-road-remix',
#    'image': 'https://is2-ssl.mzstatic.com/image/thumb/Music124/v4/07/d4/c3/07d4c33e-b793-d78f-bb1b-52f1e224da88/886447788264.jpg/400x400cc.jpg',
#    'twitter': 'I used @Shazam to discover Old Town Road (Remix) by Lil Nas X Feat. Billy Ray Cyrus.',
#    'html': 'https://www.shazam.com/snippets/email-share/463807349?lang=en&country=GB',
#    'avatar': 'https://is5-ssl.mzstatic.com/image/thumb/Features125/v4/07/89/a3/0789a358-0ee5-6f13-8a54-8dc1a113066a/pr_source.png/800x800cc.jpg',
#    'snapchat': 'https://www.shazam.com/partner/sc/track/463807349'},
#   'hub': {'type': 'APPLEMUSIC',
#    'image': 'https://images.shazam.com/static/icons/hub/web/v5/applemusic.png',
#    'actions': [{'name': 'apple', 'type': 'applemusicplay', 'id': '1468166326'},
#     {'name': 'apple',
#      'type': 'uri',
#      'uri': 'https://audio-ssl.itunes.apple.com/itunes-assets/AudioPreview125/v4/df/c5/d9/dfc5d936-099d-8c34-3a52-209164115571/mzaf_11676247829724393400.plus.aac.ep.m4a'}],
#    'options': [{'caption': 'OPEN',
#      'actions': [{'name': 'hub:applemusic:deeplink',
#        'type': 'applemusicopen',
#        'uri': 'https://music.apple.com/gb/album/old-town-road-feat-billy-ray-cyrus-remix/1468166325?i=1468166326&mttnagencyid=s2n&mttnsiteid=125115&mttn3pid=Apple-Shazam&mttnsub1=Shazam_web&mttnsub2=5348615A-616D-3235-3830-44754D6D5973&itscg=30201&app=music&itsct=Shazam_web'},
#       {'name': 'hub:applemusic:deeplink',
#        'type': 'uri',
#        'uri': 'https://music.apple.com/gb/album/old-town-road-feat-billy-ray-cyrus-remix/1468166325?i=1468166326&mttnagencyid=s2n&mttnsiteid=125115&mttn3pid=Apple-Shazam&mttnsub1=Shazam_web&mttnsub2=5348615A-616D-3235-3830-44754D6D5973&itscg=30201&app=music&itsct=Shazam_web'}],
#      'beacondata': {'type': 'open', 'providername': 'applemusic'},
#      'image': 'https://images.shazam.com/static/icons/hub/web/v5/overflow-open-option.png',
#      'type': 'open',
#      'listcaption': 'Open in Apple Music',
#      'overflowimage': 'https://images.shazam.com/static/icons/hub/web/v5/applemusic-overflow.png',
#      'colouroverflowimage': False,
#      'providername': 'applemusic'}],
#    'explicit': False,
#    'displayname': 'APPLE MUSIC'},
#   'artists': [{'follow': {'followkey': 'A_205070255'},
#     'alias': 'lil-nas-x',
#     'id': '205070255',
#     'adamid': '1400730578'}]},
#  {'id': '559530353',
#   'type': 'MUSIC',
#   'layout': '5',
#   'title': "Thinking 'Bout You",
#   'url': 'https://www.shazam.com/track/559530353/thinking-bout-you',
#   'apple_music_url': 'https://music.apple.com/gb/album/thinking-bout-you-feat-mackenzie-porter/1555342274',
#   'subtitle': 'Dustin Lynch Feat. MacKenzie Porter',
#   'images': {'background': 'https://is1-ssl.mzstatic.com/image/thumb/Features115/v4/89/92/3a/89923a44-9a42-d71c-c1cb-2a650e7c4acd/pr_source.png/800x800cc.jpg',
#    'coverart': 'https://is2-ssl.mzstatic.com/image/thumb/Music114/v4/05/f9/a6/05f9a603-5011-4c33-e499-96decb119633/4050538671971.jpg/400x400cc.jpg',
#    'coverarthq': 'https://is2-ssl.mzstatic.com/image/thumb/Music114/v4/05/f9/a6/05f9a603-5011-4c33-e499-96decb119633/4050538671971.jpg/400x400cc.jpg',
#    'joecolor': 'b:fbca90p:0e0a0ds:391f1at:3e3027q:5f4132'},
#   'share': {'subject': "Thinking 'Bout You - Dustin Lynch Feat. MacKenzie Porter",
#    'text': "I used Shazam to discover Thinking 'Bout You by Dustin Lynch Feat. MacKenzie Porter.",
#    'href': 'https://www.shazam.com/track/559530353/thinking-bout-you',
#    'image': 'https://is2-ssl.mzstatic.com/image/thumb/Music114/v4/05/f9/a6/05f9a603-5011-4c33-e499-96decb119633/4050538671971.jpg/400x400cc.jpg',
#    'twitter': "I used @Shazam to discover Thinking 'Bout You by Dustin Lynch Feat. MacKenzie Porter.",
#    'html': 'https://www.shazam.com/snippets/email-share/559530353?lang=en&country=GB',
#    'avatar': 'https://is1-ssl.mzstatic.com/image/thumb/Features115/v4/89/92/3a/89923a44-9a42-d71c-c1cb-2a650e7c4acd/pr_source.png/800x800cc.jpg',
#    'snapchat': 'https://www.shazam.com/partner/sc/track/559530353'},
#   'hub': {'type': 'APPLEMUSIC',
#    'image': 'https://images.shazam.com/static/icons/hub/web/v5/applemusic.png',
#    'actions': [{'name': 'apple', 'type': 'applemusicplay', 'id': '1555342421'},
#     {'name': 'apple',
#      'type': 'uri',
#      'uri': 'https://audio-ssl.itunes.apple.com/itunes-assets/AudioPreview114/v4/76/ba/85/76ba85ff-7e5d-2a0d-8f58-2417ca4faabe/mzaf_10240713329349789289.plus.aac.ep.m4a'}],
#    'options': [{'caption': 'OPEN',
#      'actions': [{'name': 'hub:applemusic:deeplink',
#        'type': 'applemusicopen',
#        'uri': 'https://music.apple.com/gb/album/thinking-bout-you-feat-mackenzie-porter/1555342274?i=1555342421&mttnagencyid=s2n&mttnsiteid=125115&mttn3pid=Apple-Shazam&mttnsub1=Shazam_web&mttnsub2=5348615A-616D-3235-3830-44754D6D5973&itscg=30201&app=music&itsct=Shazam_web'},
#       {'name': 'hub:applemusic:deeplink',
#        'type': 'uri',
#        'uri': 'https://music.apple.com/gb/album/thinking-bout-you-feat-mackenzie-porter/1555342274?i=1555342421&mttnagencyid=s2n&mttnsiteid=125115&mttn3pid=Apple-Shazam&mttnsub1=Shazam_web&mttnsub2=5348615A-616D-3235-3830-44754D6D5973&itscg=30201&app=music&itsct=Shazam_web'}],
#      'beacondata': {'type': 'open', 'providername': 'applemusic'},
#      'image': 'https://images.shazam.com/static/icons/hub/web/v5/overflow-open-option.png',
#      'type': 'open',
#      'listcaption': 'Open in Apple Music',
#      'overflowimage': 'https://images.shazam.com/static/icons/hub/web/v5/applemusic-overflow.png',
#      'colouroverflowimage': False,
#      'providername': 'applemusic'}],
#    'explicit': False,
#    'displayname': 'APPLE MUSIC'},
#   'artists': [{'follow': {'followkey': 'A_41025950'},
#     'alias': 'dustin-lynch',
#     'id': '41025950',
#     'adamid': '493220807'}]},
#  {'id': '49944455',
#   'type': 'MUSIC',
#   'layout': '5',
#   'title': 'Need You Now',
#   'url': 'https://www.shazam.com/track/49944455/need-you-now',
#   'apple_music_url': 'https://music.apple.com/gb/album/need-you-now/716298939',
#   'subtitle': 'Lady Antebellum',
#   'images': {'background': 'https://is1-ssl.mzstatic.com/image/thumb/Music124/v4/91/b2/39/91b23943-dca8-c996-5e5d-a28723b546c0/05099964055657.rgb.jpg/400x400cc.jpg',
#    'coverart': 'https://is1-ssl.mzstatic.com/image/thumb/Music124/v4/91/b2/39/91b23943-dca8-c996-5e5d-a28723b546c0/05099964055657.rgb.jpg/400x400cc.jpg',
#    'coverarthq': 'https://is1-ssl.mzstatic.com/image/thumb/Music124/v4/91/b2/39/91b23943-dca8-c996-5e5d-a28723b546c0/05099964055657.rgb.jpg/400x400cc.jpg',
#    'joecolor': 'b:281f16p:ffffffs:ead7cct:d3d2d0q:c3b2a8'},
#   'share': {'subject': 'Need You Now - Lady Antebellum',
#    'text': 'I used Shazam to discover Need You Now by Lady Antebellum.',
#    'href': 'https://www.shazam.com/track/49944455/need-you-now',
#    'image': 'https://is1-ssl.mzstatic.com/image/thumb/Music124/v4/91/b2/39/91b23943-dca8-c996-5e5d-a28723b546c0/05099964055657.rgb.jpg/400x400cc.jpg',
#    'twitter': 'I used @Shazam to discover Need You Now by Lady Antebellum.',
#    'html': 'https://www.shazam.com/snippets/email-share/49944455?lang=en&country=GB',
#    'snapchat': 'https://www.shazam.com/partner/sc/track/49944455'},
#   'hub': {'type': 'APPLEMUSIC',
#    'image': 'https://images.shazam.com/static/icons/hub/web/v5/applemusic.png',
#    'actions': [{'name': 'apple', 'type': 'applemusicplay', 'id': '716299227'},
#     {'name': 'apple',
#      'type': 'uri',
#      'uri': 'https://audio-ssl.itunes.apple.com/itunes-assets/AudioPreview115/v4/77/63/2d/77632dc6-c3db-ea64-98d0-60f0280fba0a/mzaf_756437969246482516.plus.aac.ep.m4a'}],
#    'options': [{'caption': 'OPEN',
#      'actions': [{'name': 'hub:applemusic:deeplink',
#        'type': 'applemusicopen',
#        'uri': 'https://music.apple.com/gb/album/need-you-now/716298939?i=716299227&mttnagencyid=s2n&mttnsiteid=125115&mttn3pid=Apple-Shazam&mttnsub1=Shazam_web&mttnsub2=5348615A-616D-3235-3830-44754D6D5973&itscg=30201&app=music&itsct=Shazam_web'},
#       {'name': 'hub:applemusic:deeplink',
#        'type': 'uri',
#        'uri': 'https://music.apple.com/gb/album/need-you-now/716298939?i=716299227&mttnagencyid=s2n&mttnsiteid=125115&mttn3pid=Apple-Shazam&mttnsub1=Shazam_web&mttnsub2=5348615A-616D-3235-3830-44754D6D5973&itscg=30201&app=music&itsct=Shazam_web'}],
#      'beacondata': {'type': 'open', 'providername': 'applemusic'},
#      'image': 'https://images.shazam.com/static/icons/hub/web/v5/overflow-open-option.png',
#      'type': 'open',
#      'listcaption': 'Open in Apple Music',
#      'overflowimage': 'https://images.shazam.com/static/icons/hub/web/v5/applemusic-overflow.png',
#      'colouroverflowimage': False,
#      'providername': 'applemusic'}],
#    'explicit': False,
#    'displayname': 'APPLE MUSIC'},
#   'artists': [{'follow': {'followkey': 'A_40227253'},
#     'alias': 'lady-antebellum',
#     'id': '40227253'}]},
#  {'id': '566885142',
#   'type': 'MUSIC',
#   'layout': '5',
#   'title': 'Buy Dirt [Acoustic]',
#   'url': 'https://www.shazam.com/track/566885142/buy-dirt-acoustic',
#   'apple_music_url': 'https://music.apple.com/gb/album/buy-dirt-feat-luke-bryan-acoustic/1589132937',
#   'subtitle': 'Jordan Davis Feat. Luke Bryan',
#   'images': {'background': 'https://is5-ssl.mzstatic.com/image/thumb/Features125/v4/be/33/af/be33af68-d207-b885-7402-a8635c05203e/pr_source.png/800x800cc.jpg',
#    'coverart': 'https://is1-ssl.mzstatic.com/image/thumb/Music115/v4/ad/f7/d8/adf7d867-4615-1f87-9fdf-2c10adcacbd8/21UM1IM23122.rgb.jpg/400x400cc.jpg',
#    'coverarthq': 'https://is1-ssl.mzstatic.com/image/thumb/Music115/v4/ad/f7/d8/adf7d867-4615-1f87-9fdf-2c10adcacbd8/21UM1IM23122.rgb.jpg/400x400cc.jpg',
#    'joecolor': 'b:1a1a1ap:eaeaeas:cccccct:c0c0c0q:a8a8a8'},
#   'share': {'subject': 'Buy Dirt [Acoustic] - Jordan Davis Feat. Luke Bryan',
#    'text': 'I used Shazam to discover Buy Dirt [Acoustic] by Jordan Davis Feat. Luke Bryan.',
#    'href': 'https://www.shazam.com/track/566885142/buy-dirt-acoustic',
#    'image': 'https://is1-ssl.mzstatic.com/image/thumb/Music115/v4/ad/f7/d8/adf7d867-4615-1f87-9fdf-2c10adcacbd8/21UM1IM23122.rgb.jpg/400x400cc.jpg',
#    'twitter': 'I used @Shazam to discover Buy Dirt [Acoustic] by Jordan Davis Feat. Luke Bryan.',
#    'html': 'https://www.shazam.com/snippets/email-share/566885142?lang=en&country=GB',
#    'avatar': 'https://is5-ssl.mzstatic.com/image/thumb/Features125/v4/be/33/af/be33af68-d207-b885-7402-a8635c05203e/pr_source.png/800x800cc.jpg',
#    'snapchat': 'https://www.shazam.com/partner/sc/track/566885142'},
#   'hub': {'type': 'APPLEMUSIC',
#    'image': 'https://images.shazam.com/static/icons/hub/web/v5/applemusic.png',
#    'actions': [{'name': 'apple', 'type': 'applemusicplay', 'id': '1589132940'},
#     {'name': 'apple',
#      'type': 'uri',
#      'uri': 'https://audio-ssl.itunes.apple.com/itunes-assets/AudioPreview125/v4/b8/ff/47/b8ff47e4-53b1-e8f3-eeb1-7d4f1726cc06/mzaf_17075214069879833941.plus.aac.ep.m4a'}],
#    'options': [{'caption': 'OPEN',
#      'actions': [{'name': 'hub:applemusic:deeplink',
#        'type': 'applemusicopen',
#        'uri': 'https://music.apple.com/gb/album/buy-dirt-feat-luke-bryan-acoustic/1589132937?i=1589132940&mttnagencyid=s2n&mttnsiteid=125115&mttn3pid=Apple-Shazam&mttnsub1=Shazam_web&mttnsub2=5348615A-616D-3235-3830-44754D6D5973&itscg=30201&app=music&itsct=Shazam_web'},
#       {'name': 'hub:applemusic:deeplink',
#        'type': 'uri',
#        'uri': 'https://music.apple.com/gb/album/buy-dirt-feat-luke-bryan-acoustic/1589132937?i=1589132940&mttnagencyid=s2n&mttnsiteid=125115&mttn3pid=Apple-Shazam&mttnsub1=Shazam_web&mttnsub2=5348615A-616D-3235-3830-44754D6D5973&itscg=30201&app=music&itsct=Shazam_web'}],
#      'beacondata': {'type': 'open', 'providername': 'applemusic'},
#      'image': 'https://images.shazam.com/static/icons/hub/web/v5/overflow-open-option.png',
#      'type': 'open',
#      'listcaption': 'Open in Apple Music',
#      'overflowimage': 'https://images.shazam.com/static/icons/hub/web/v5/applemusic-overflow.png',
#      'colouroverflowimage': False,
#      'providername': 'applemusic'}],
#    'explicit': False,
#    'displayname': 'APPLE MUSIC'},
#   'artists': [{'follow': {'followkey': 'A_43783810'},
#     'alias': 'jordan-davis',
#     'id': '43783810',
#     'adamid': '1240921740'}]},
#  {'id': '534468438',
#   'type': 'MUSIC',
#   'layout': '5',
#   'title': 'You Should Probably Leave',
#   'url': 'https://www.shazam.com/track/534468438/you-should-probably-leave',
#   'apple_music_url': 'https://music.apple.com/gb/album/you-should-probably-leave/1528423147',
#   'subtitle': 'Chris Stapleton',
#   'images': {'background': 'https://is2-ssl.mzstatic.com/image/thumb/Features115/v4/4b/4f/b0/4b4fb07e-8690-16cf-06fe-b3f259a077e8/pr_source.png/800x800cc.jpg',
#    'coverart': 'https://is3-ssl.mzstatic.com/image/thumb/Music115/v4/34/12/78/34127801-ad2b-4469-4916-d661bba34a94/20UMGIM71875.rgb.jpg/400x400cc.jpg',
#    'coverarthq': 'https://is3-ssl.mzstatic.com/image/thumb/Music115/v4/34/12/78/34127801-ad2b-4469-4916-d661bba34a94/20UMGIM71875.rgb.jpg/400x400cc.jpg',
#    'joecolor': 'b:f3f3f3p:09090as:2f2e33t:383838q:56565a'},
#   'share': {'subject': 'You Should Probably Leave - Chris Stapleton',
#    'text': 'I used Shazam to discover You Should Probably Leave by Chris Stapleton.',
#    'href': 'https://www.shazam.com/track/534468438/you-should-probably-leave',
#    'image': 'https://is3-ssl.mzstatic.com/image/thumb/Music115/v4/34/12/78/34127801-ad2b-4469-4916-d661bba34a94/20UMGIM71875.rgb.jpg/400x400cc.jpg',
#    'twitter': 'I used @Shazam to discover You Should Probably Leave by Chris Stapleton.',
#    'html': 'https://www.shazam.com/snippets/email-share/534468438?lang=en&country=GB',
#    'avatar': 'https://is2-ssl.mzstatic.com/image/thumb/Features115/v4/4b/4f/b0/4b4fb07e-8690-16cf-06fe-b3f259a077e8/pr_source.png/800x800cc.jpg',
#    'snapchat': 'https://www.shazam.com/partner/sc/track/534468438'},
#   'hub': {'type': 'APPLEMUSIC',
#    'image': 'https://images.shazam.com/static/icons/hub/web/v5/applemusic.png',
#    'actions': [{'name': 'apple', 'type': 'applemusicplay', 'id': '1528423169'},
#     {'name': 'apple',
#      'type': 'uri',
#      'uri': 'https://audio-ssl.itunes.apple.com/itunes-assets/AudioPreview125/v4/74/33/f1/7433f129-d852-28b0-bd48-aadd88d234ee/mzaf_8154648826991710574.plus.aac.ep.m4a'}],
#    'options': [{'caption': 'OPEN',
#      'actions': [{'name': 'hub:applemusic:deeplink',
#        'type': 'applemusicopen',
#        'uri': 'https://music.apple.com/gb/album/you-should-probably-leave/1528423147?i=1528423169&mttnagencyid=s2n&mttnsiteid=125115&mttn3pid=Apple-Shazam&mttnsub1=Shazam_web&mttnsub2=5348615A-616D-3235-3830-44754D6D5973&itscg=30201&app=music&itsct=Shazam_web'},
#       {'name': 'hub:applemusic:deeplink',
#        'type': 'uri',
#        'uri': 'https://music.apple.com/gb/album/you-should-probably-leave/1528423147?i=1528423169&mttnagencyid=s2n&mttnsiteid=125115&mttn3pid=Apple-Shazam&mttnsub1=Shazam_web&mttnsub2=5348615A-616D-3235-3830-44754D6D5973&itscg=30201&app=music&itsct=Shazam_web'}],
#      'beacondata': {'type': 'open', 'providername': 'applemusic'},
#      'image': 'https://images.shazam.com/static/icons/hub/web/v5/overflow-open-option.png',
#      'type': 'open',
#      'listcaption': 'Open in Apple Music',
#      'overflowimage': 'https://images.shazam.com/static/icons/hub/web/v5/applemusic-overflow.png',
#      'colouroverflowimage': False,
#      'providername': 'applemusic'}],
#    'explicit': False,
#    'displayname': 'APPLE MUSIC'},
#   'artists': [{'follow': {'followkey': 'A_40229488'},
#     'alias': 'chris-stapleton',
#     'id': '40229488',
#     'adamid': '1752134'}]},
#  {'id': '545409566',
#   'type': 'MUSIC',
#   'layout': '5',
#   'title': 'Sand In My Boots',
#   'url': 'https://www.shazam.com/track/545409566/sand-in-my-boots',
#   'apple_music_url': 'https://music.apple.com/gb/album/sand-in-my-boots/1540313604',
#   'subtitle': 'Morgan Wallen',
#   'images': {'background': 'https://is4-ssl.mzstatic.com/image/thumb/Music115/v4/74/d6/33/74d6338a-edeb-2011-e1a0-d5b40f052371/pr_source.png/800x800cc.jpg',
#    'coverart': 'https://is3-ssl.mzstatic.com/image/thumb/Music114/v4/9f/8d/c5/9f8dc5cd-1e4b-2259-1e4a-fe328c13be27/20UM1IM03632.rgb.jpg/400x400cc.jpg',
#    'coverarthq': 'https://is3-ssl.mzstatic.com/image/thumb/Music114/v4/9f/8d/c5/9f8dc5cd-1e4b-2259-1e4a-fe328c13be27/20UM1IM03632.rgb.jpg/400x400cc.jpg',
#    'joecolor': 'b:15272ep:f3e3dcs:bdc5bft:c7beb9q:9ba5a2'},
#   'share': {'subject': 'Sand In My Boots - Morgan Wallen',
#    'text': 'I used Shazam to discover Sand In My Boots by Morgan Wallen.',
#    'href': 'https://www.shazam.com/track/545409566/sand-in-my-boots',
#    'image': 'https://is3-ssl.mzstatic.com/image/thumb/Music114/v4/9f/8d/c5/9f8dc5cd-1e4b-2259-1e4a-fe328c13be27/20UM1IM03632.rgb.jpg/400x400cc.jpg',
#    'twitter': 'I used @Shazam to discover Sand In My Boots by Morgan Wallen.',
#    'html': 'https://www.shazam.com/snippets/email-share/545409566?lang=en&country=GB',
#    'avatar': 'https://is4-ssl.mzstatic.com/image/thumb/Music115/v4/74/d6/33/74d6338a-edeb-2011-e1a0-d5b40f052371/pr_source.png/800x800cc.jpg',
#    'snapchat': 'https://www.shazam.com/partner/sc/track/545409566'},
#   'hub': {'type': 'APPLEMUSIC',
#    'image': 'https://images.shazam.com/static/icons/hub/web/v5/applemusic.png',
#    'actions': [{'name': 'apple', 'type': 'applemusicplay', 'id': '1540313610'},
#     {'name': 'apple',
#      'type': 'uri',
#      'uri': 'https://audio-ssl.itunes.apple.com/itunes-assets/AudioPreview115/v4/35/5d/17/355d17aa-d05a-d7a1-6006-b36393f0d99c/mzaf_3471217906518419438.plus.aac.ep.m4a'}],
#    'options': [{'caption': 'OPEN',
#      'actions': [{'name': 'hub:applemusic:deeplink',
#        'type': 'applemusicopen',
#        'uri': 'https://music.apple.com/gb/album/sand-in-my-boots/1540313604?i=1540313610&mttnagencyid=s2n&mttnsiteid=125115&mttn3pid=Apple-Shazam&mttnsub1=Shazam_web&mttnsub2=5348615A-616D-3235-3830-44754D6D5973&itscg=30201&app=music&itsct=Shazam_web'},
#       {'name': 'hub:applemusic:deeplink',
#        'type': 'uri',
#        'uri': 'https://music.apple.com/gb/album/sand-in-my-boots/1540313604?i=1540313610&mttnagencyid=s2n&mttnsiteid=125115&mttn3pid=Apple-Shazam&mttnsub1=Shazam_web&mttnsub2=5348615A-616D-3235-3830-44754D6D5973&itscg=30201&app=music&itsct=Shazam_web'}],
#      'beacondata': {'type': 'open', 'providername': 'applemusic'},
#      'image': 'https://images.shazam.com/static/icons/hub/web/v5/overflow-open-option.png',
#      'type': 'open',
#      'listcaption': 'Open in Apple Music',
#      'overflowimage': 'https://images.shazam.com/static/icons/hub/web/v5/applemusic-overflow.png',
#      'colouroverflowimage': False,
#      'providername': 'applemusic'}],
#    'explicit': False,
#    'displayname': 'APPLE MUSIC'},
#   'artists': [{'follow': {'followkey': 'A_44693072'},
#     'alias': 'morgan-wallen',
#     'id': '44693072',
#     'adamid': '829142092'}]},
#  {'id': '536859303',
#   'type': 'MUSIC',
#   'layout': '5',
#   'title': 'Whiskey And Rain',
#   'url': 'https://www.shazam.com/track/536859303/whiskey-and-rain',
#   'apple_music_url': 'https://music.apple.com/gb/album/whiskey-and-rain/1578356664',
#   'subtitle': 'Michael Ray',
#   'images': {'background': 'https://is2-ssl.mzstatic.com/image/thumb/Music125/v4/ab/7c/42/ab7c42df-024e-53fa-2bc6-e0a21a9197c1/pr_source.png/800x800cc.jpg',
#    'coverart': 'https://is2-ssl.mzstatic.com/image/thumb/Music125/v4/1c/c7/ef/1cc7efc0-d91d-cc1a-9b63-b22079842afb/093624878292.jpg/400x400cc.jpg',
#    'coverarthq': 'https://is2-ssl.mzstatic.com/image/thumb/Music125/v4/1c/c7/ef/1cc7efc0-d91d-cc1a-9b63-b22079842afb/093624878292.jpg/400x400cc.jpg',
#    'joecolor': 'b:efeeeap:0f0d0cs:242423t:3c3a38q:4d4c4b'},
#   'share': {'subject': 'Whiskey And Rain - Michael Ray',
#    'text': 'I used Shazam to discover Whiskey And Rain by Michael Ray.',
#    'href': 'https://www.shazam.com/track/536859303/whiskey-and-rain',
#    'image': 'https://is2-ssl.mzstatic.com/image/thumb/Music125/v4/1c/c7/ef/1cc7efc0-d91d-cc1a-9b63-b22079842afb/093624878292.jpg/400x400cc.jpg',
#    'twitter': 'I used @Shazam to discover Whiskey And Rain by Michael Ray.',
#    'html': 'https://www.shazam.com/snippets/email-share/536859303?lang=en&country=GB',
#    'avatar': 'https://is2-ssl.mzstatic.com/image/thumb/Music125/v4/ab/7c/42/ab7c42df-024e-53fa-2bc6-e0a21a9197c1/pr_source.png/800x800cc.jpg',
#    'snapchat': 'https://www.shazam.com/partner/sc/track/536859303'},
#   'hub': {'type': 'APPLEMUSIC',
#    'image': 'https://images.shazam.com/static/icons/hub/web/v5/applemusic.png',
#    'actions': [{'name': 'apple', 'type': 'applemusicplay', 'id': '1578357156'},
#     {'name': 'apple',
#      'type': 'uri',
#      'uri': 'https://audio-ssl.itunes.apple.com/itunes-assets/AudioPreview115/v4/3f/bb/ed/3fbbed74-cda9-2e93-d786-73b6bfb39cc3/mzaf_14539684710526146082.plus.aac.ep.m4a'}],
#    'options': [{'caption': 'OPEN',
#      'actions': [{'name': 'hub:applemusic:deeplink',
#        'type': 'applemusicopen',
#        'uri': 'https://music.apple.com/gb/album/whiskey-and-rain/1578356664?i=1578357156&mttnagencyid=s2n&mttnsiteid=125115&mttn3pid=Apple-Shazam&mttnsub1=Shazam_web&mttnsub2=5348615A-616D-3235-3830-44754D6D5973&itscg=30201&app=music&itsct=Shazam_web'},
#       {'name': 'hub:applemusic:deeplink',
#        'type': 'uri',
#        'uri': 'https://music.apple.com/gb/album/whiskey-and-rain/1578356664?i=1578357156&mttnagencyid=s2n&mttnsiteid=125115&mttn3pid=Apple-Shazam&mttnsub1=Shazam_web&mttnsub2=5348615A-616D-3235-3830-44754D6D5973&itscg=30201&app=music&itsct=Shazam_web'}],
#      'beacondata': {'type': 'open', 'providername': 'applemusic'},
#      'image': 'https://images.shazam.com/static/icons/hub/web/v5/overflow-open-option.png',
#      'type': 'open',
#      'listcaption': 'Open in Apple Music',
#      'overflowimage': 'https://images.shazam.com/static/icons/hub/web/v5/applemusic-overflow.png',
#      'colouroverflowimage': False,
#      'providername': 'applemusic'}],
#    'explicit': False,
#    'displayname': 'APPLE MUSIC'},
#   'artists': [{'follow': {'followkey': 'A_35868'},
#     'alias': 'michael-ray',
#     'id': '35868',
#     'adamid': '963306250'}]},
#  {'id': '456773549',
#   'type': 'MUSIC',
#   'layout': '5',
#   'title': 'I Hope',
#   'url': 'https://www.shazam.com/track/456773549/i-hope',
#   'apple_music_url': 'https://music.apple.com/gb/album/i-hope/1510409258',
#   'subtitle': 'Gabby Barrett',
#   'images': {'background': 'https://is3-ssl.mzstatic.com/image/thumb/Music116/v4/01/ce/b7/01ceb768-ee9f-dd77-f3c6-371528642001/pr_source.png/800x800cc.jpg',
#    'coverart': 'https://is5-ssl.mzstatic.com/image/thumb/Music124/v4/4c/24/a3/4c24a36c-cbba-2c19-86ed-1b2df12e8730/093624893301.jpg/400x400cc.jpg',
#    'coverarthq': 'https://is5-ssl.mzstatic.com/image/thumb/Music124/v4/4c/24/a3/4c24a36c-cbba-2c19-86ed-1b2df12e8730/093624893301.jpg/400x400cc.jpg',
#    'joecolor': 'b:d9d5d4p:0e0d0es:101010t:363536q:383737'},
#   'share': {'subject': 'I Hope - Gabby Barrett',
#    'text': 'I used Shazam to discover I Hope by Gabby Barrett.',
#    'href': 'https://www.shazam.com/track/456773549/i-hope',
#    'image': 'https://is5-ssl.mzstatic.com/image/thumb/Music124/v4/4c/24/a3/4c24a36c-cbba-2c19-86ed-1b2df12e8730/093624893301.jpg/400x400cc.jpg',
#    'twitter': 'I used @Shazam to discover I Hope by Gabby Barrett.',
#    'html': 'https://www.shazam.com/snippets/email-share/456773549?lang=en&country=GB',
#    'avatar': 'https://is3-ssl.mzstatic.com/image/thumb/Music116/v4/01/ce/b7/01ceb768-ee9f-dd77-f3c6-371528642001/pr_source.png/800x800cc.jpg',
#    'snapchat': 'https://www.shazam.com/partner/sc/track/456773549'},
#   'hub': {'type': 'APPLEMUSIC',
#    'image': 'https://images.shazam.com/static/icons/hub/web/v5/applemusic.png',
#    'actions': [{'name': 'apple', 'type': 'applemusicplay', 'id': '1510409259'},
#     {'name': 'apple',
#      'type': 'uri',
#      'uri': 'https://audio-ssl.itunes.apple.com/itunes-assets/AudioPreview125/v4/9d/3d/fe/9d3dfee1-8091-1af3-7b95-b2724e50c3e6/mzaf_3746143083033239696.plus.aac.ep.m4a'}],
#    'options': [{'caption': 'OPEN',
#      'actions': [{'name': 'hub:applemusic:deeplink',
#        'type': 'applemusicopen',
#        'uri': 'https://music.apple.com/gb/album/i-hope/1510409258?i=1510409259&mttnagencyid=s2n&mttnsiteid=125115&mttn3pid=Apple-Shazam&mttnsub1=Shazam_web&mttnsub2=5348615A-616D-3235-3830-44754D6D5973&itscg=30201&app=music&itsct=Shazam_web'},
#       {'name': 'hub:applemusic:deeplink',
#        'type': 'uri',
#        'uri': 'https://music.apple.com/gb/album/i-hope/1510409258?i=1510409259&mttnagencyid=s2n&mttnsiteid=125115&mttn3pid=Apple-Shazam&mttnsub1=Shazam_web&mttnsub2=5348615A-616D-3235-3830-44754D6D5973&itscg=30201&app=music&itsct=Shazam_web'}],
#      'beacondata': {'type': 'open', 'providername': 'applemusic'},
#      'image': 'https://images.shazam.com/static/icons/hub/web/v5/overflow-open-option.png',
#      'type': 'open',
#      'listcaption': 'Open in Apple Music',
#      'overflowimage': 'https://images.shazam.com/static/icons/hub/web/v5/applemusic-overflow.png',
#      'colouroverflowimage': False,
#      'providername': 'applemusic'}],
#    'explicit': False,
#    'displayname': 'APPLE MUSIC'},
#   'artists': [{'follow': {'followkey': 'A_45141998'},
#     'alias': 'gabby-barrett',
#     'id': '45141998',
#     'adamid': '623856508'}]},
#  {'id': '577099928',
#   'type': 'MUSIC',
#   'layout': '5',
#   'title': "If I Didn't Love You",
#   'url': 'https://www.shazam.com/track/577099928/if-i-didnt-love-you',
#   'apple_music_url': 'https://music.apple.com/gb/album/if-i-didnt-love-you/1584827718',
#   'subtitle': 'Jason Aldean & Carrie Underwood',
#   'images': {'background': 'https://is5-ssl.mzstatic.com/image/thumb/Music125/v4/d4/3b/e0/d43be00d-ba4b-219c-4dd8-cd91f486800b/pr_source.png/800x800cc.jpg',
#    'coverart': 'https://is5-ssl.mzstatic.com/image/thumb/Music115/v4/af/56/0e/af560ebb-d38b-5d9b-e62f-8caefd6071d2/4050538719116.jpg/400x400cc.jpg',
#    'coverarthq': 'https://is5-ssl.mzstatic.com/image/thumb/Music115/v4/af/56/0e/af560ebb-d38b-5d9b-e62f-8caefd6071d2/4050538719116.jpg/400x400cc.jpg',
#    'joecolor': 'b:e1c88fp:341b02s:3f190dt:563d1eq:603c27'},
#   'share': {'subject': "If I Didn't Love You - Jason Aldean & Carrie Underwood",
#    'text': "I used Shazam to discover If I Didn't Love You by Jason Aldean & Carrie Underwood.",
#    'href': 'https://www.shazam.com/track/577099928/if-i-didnt-love-you',
#    'image': 'https://is5-ssl.mzstatic.com/image/thumb/Music115/v4/af/56/0e/af560ebb-d38b-5d9b-e62f-8caefd6071d2/4050538719116.jpg/400x400cc.jpg',
#    'twitter': "I used @Shazam to discover If I Didn't Love You by Jason Aldean & Carrie Underwood.",
#    'html': 'https://www.shazam.com/snippets/email-share/577099928?lang=en&country=GB',
#    'avatar': 'https://is5-ssl.mzstatic.com/image/thumb/Music125/v4/d4/3b/e0/d43be00d-ba4b-219c-4dd8-cd91f486800b/pr_source.png/800x800cc.jpg',
#    'snapchat': 'https://www.shazam.com/partner/sc/track/577099928'},
#   'hub': {'type': 'APPLEMUSIC',
#    'image': 'https://images.shazam.com/static/icons/hub/web/v5/applemusic.png',
#    'actions': [{'name': 'apple', 'type': 'applemusicplay', 'id': '1584827733'},
#     {'name': 'apple',
#      'type': 'uri',
#      'uri': 'https://audio-ssl.itunes.apple.com/itunes-assets/AudioPreview116/v4/25/15/ed/2515edea-e474-8ac8-cd67-e2b271a0eac4/mzaf_7628320318953284884.plus.aac.ep.m4a'}],
#    'options': [{'caption': 'OPEN',
#      'actions': [{'name': 'hub:applemusic:deeplink',
#        'type': 'applemusicopen',
#        'uri': 'https://music.apple.com/gb/album/if-i-didnt-love-you/1584827718?i=1584827733&mttnagencyid=s2n&mttnsiteid=125115&mttn3pid=Apple-Shazam&mttnsub1=Shazam_web&mttnsub2=5348615A-616D-3235-3830-44754D6D5973&itscg=30201&app=music&itsct=Shazam_web'},
#       {'name': 'hub:applemusic:deeplink',
#        'type': 'uri',
#        'uri': 'https://music.apple.com/gb/album/if-i-didnt-love-you/1584827718?i=1584827733&mttnagencyid=s2n&mttnsiteid=125115&mttn3pid=Apple-Shazam&mttnsub1=Shazam_web&mttnsub2=5348615A-616D-3235-3830-44754D6D5973&itscg=30201&app=music&itsct=Shazam_web'}],
#      'beacondata': {'type': 'open', 'providername': 'applemusic'},
#      'image': 'https://images.shazam.com/static/icons/hub/web/v5/overflow-open-option.png',
#      'type': 'open',
#      'listcaption': 'Open in Apple Music',
#      'overflowimage': 'https://images.shazam.com/static/icons/hub/web/v5/applemusic-overflow.png',
#      'colouroverflowimage': False,
#      'providername': 'applemusic'}],
#    'explicit': False,
#    'displayname': 'APPLE MUSIC'},
#   'artists': [{'follow': {'followkey': 'A_40083452'},
#     'alias': 'jason-aldean',
#     'id': '40083452',
#     'adamid': '63684710'},
#    {'follow': {'followkey': 'A_40098631'},
#     'alias': 'carrie-underwood',
#     'id': '40098631',
#     'adamid': '63399334'}]},
#  {'id': '572189529',
#   'type': 'MUSIC',
#   'layout': '5',
#   'title': "'Til You Can't",
#   'url': 'https://www.shazam.com/track/572189529/til-you-cant',
#   'apple_music_url': 'https://music.apple.com/gb/album/til-you-cant/1582024378',
#   'subtitle': 'Cody Johnson',
#   'images': {'background': 'https://is1-ssl.mzstatic.com/image/thumb/Music125/v4/e9/41/5e/e9415e21-4bc5-b782-7d3b-51fd471d1d66/pr_source.png/800x800cc.jpg',
#    'coverart': 'https://is3-ssl.mzstatic.com/image/thumb/Music115/v4/8b/4d/54/8b4d545d-feee-c91c-992c-cecd16677f6e/093624879381.jpg/400x400cc.jpg',
#    'coverarthq': 'https://is3-ssl.mzstatic.com/image/thumb/Music115/v4/8b/4d/54/8b4d545d-feee-c91c-992c-cecd16677f6e/093624879381.jpg/400x400cc.jpg',
#    'joecolor': 'b:9da5a7p:000e09s:2c1e13t:202c28q:423931'},
#   'share': {'subject': "'Til You Can't - Cody Johnson",
#    'text': "I used Shazam to discover 'Til You Can't by Cody Johnson.",
#    'href': 'https://www.shazam.com/track/572189529/til-you-cant',
#    'image': 'https://is3-ssl.mzstatic.com/image/thumb/Music115/v4/8b/4d/54/8b4d545d-feee-c91c-992c-cecd16677f6e/093624879381.jpg/400x400cc.jpg',
#    'twitter': "I used @Shazam to discover 'Til You Can't by Cody Johnson.",
#    'html': 'https://www.shazam.com/snippets/email-share/572189529?lang=en&country=GB',
#    'avatar': 'https://is1-ssl.mzstatic.com/image/thumb/Music125/v4/e9/41/5e/e9415e21-4bc5-b782-7d3b-51fd471d1d66/pr_source.png/800x800cc.jpg',
#    'snapchat': 'https://www.shazam.com/partner/sc/track/572189529'},
#   'hub': {'type': 'APPLEMUSIC',
#    'image': 'https://images.shazam.com/static/icons/hub/web/v5/applemusic.png',
#    'actions': [{'name': 'apple', 'type': 'applemusicplay', 'id': '1582024384'},
#     {'name': 'apple',
#      'type': 'uri',
#      'uri': 'https://audio-ssl.itunes.apple.com/itunes-assets/AudioPreview125/v4/9b/1b/28/9b1b2845-0daa-e1a6-1f19-e4efd7536428/mzaf_4963464460971577581.plus.aac.ep.m4a'}],
#    'options': [{'caption': 'OPEN',
#      'actions': [{'name': 'hub:applemusic:deeplink',
#        'type': 'applemusicopen',
#        'uri': 'https://music.apple.com/gb/album/til-you-cant/1582024378?i=1582024384&mttnagencyid=s2n&mttnsiteid=125115&mttn3pid=Apple-Shazam&mttnsub1=Shazam_web&mttnsub2=5348615A-616D-3235-3830-44754D6D5973&itscg=30201&app=music&itsct=Shazam_web'},
#       {'name': 'hub:applemusic:deeplink',
#        'type': 'uri',
#        'uri': 'https://music.apple.com/gb/album/til-you-cant/1582024378?i=1582024384&mttnagencyid=s2n&mttnsiteid=125115&mttn3pid=Apple-Shazam&mttnsub1=Shazam_web&mttnsub2=5348615A-616D-3235-3830-44754D6D5973&itscg=30201&app=music&itsct=Shazam_web'}],
#      'beacondata': {'type': 'open', 'providername': 'applemusic'},
#      'image': 'https://images.shazam.com/static/icons/hub/web/v5/overflow-open-option.png',
#      'type': 'open',
#      'listcaption': 'Open in Apple Music',
#      'overflowimage': 'https://images.shazam.com/static/icons/hub/web/v5/applemusic-overflow.png',
# ...
#      'image': 'https://images.shazam.com/static/icons/hub/web/v5/overflow-open-option.png',
#      'type': 'open',
#      'listcaption': 'Open in Apple Music',
#      'overflowimage': 'https://images.shazam.com/static/icons/hub/web/v5/applemusic-overflow.png',
#      'colouroverflowimage': False,
#      'providername': 'applemusic'}],
#    'explicit': False,
#    'displayname': 'APPLE MUSIC'},
#   'artists': [{'follow': {'followkey': 'A_204256134'},
#     'alias': 'priscilla-block',
#     'id': '204256134',
#     'adamid': '1246536506'}]},
#  {'id': '228197',
#   'type': 'MUSIC',
#   'layout': '5',
#   'title': 'Oh, Pretty Woman',
#   'url': 'https://www.shazam.com/track/228197/oh-pretty-woman',
#   'apple_music_url': 'https://music.apple.com/gb/album/oh-pretty-woman/872478304',
#   'subtitle': 'Roy Orbison',
#   'images': {'background': 'https://is2-ssl.mzstatic.com/image/thumb/Features115/v4/1a/44/af/1a44af66-9a9c-e3bb-071d-acc8227005fd/mza_6771763199614916975.png/800x800cc.jpg',
#    'coverart': 'https://is1-ssl.mzstatic.com/image/thumb/Music125/v4/30/a2/b6/30a2b6ef-d9fb-738c-07e5-97028b39d430/dj.hcobukpd.jpg/400x400cc.jpg',
#    'coverarthq': 'https://is1-ssl.mzstatic.com/image/thumb/Music125/v4/30/a2/b6/30a2b6ef-d9fb-738c-07e5-97028b39d430/dj.hcobukpd.jpg/400x400cc.jpg',
#    'joecolor': 'b:fdfbeep:0c0c0cs:002934t:3c3c39q:325359'},
#   'share': {'subject': 'Oh, Pretty Woman - Roy Orbison',
#    'text': 'I used Shazam to discover Oh, Pretty Woman by Roy Orbison.',
#    'href': 'https://www.shazam.com/track/228197/oh-pretty-woman',
#    'image': 'https://is1-ssl.mzstatic.com/image/thumb/Music125/v4/30/a2/b6/30a2b6ef-d9fb-738c-07e5-97028b39d430/dj.hcobukpd.jpg/400x400cc.jpg',
#    'twitter': 'I used @Shazam to discover Oh, Pretty Woman by Roy Orbison.',
#    'html': 'https://www.shazam.com/snippets/email-share/228197?lang=en&country=GB',
#    'avatar': 'https://is2-ssl.mzstatic.com/image/thumb/Features115/v4/1a/44/af/1a44af66-9a9c-e3bb-071d-acc8227005fd/mza_6771763199614916975.png/800x800cc.jpg',
#    'snapchat': 'https://www.shazam.com/partner/sc/track/228197'},
#   'hub': {'type': 'APPLEMUSIC',
#    'image': 'https://images.shazam.com/static/icons/hub/web/v5/applemusic.png',
#    'actions': [{'name': 'apple', 'type': 'applemusicplay', 'id': '872478306'},
#     {'name': 'apple',
#      'type': 'uri',
#      'uri': 'https://audio-ssl.itunes.apple.com/itunes-assets/AudioPreview115/v4/8e/c9/dc/8ec9dc28-36ac-9a72-0fa3-bd3b96f6d119/mzaf_4649210905140662585.plus.aac.ep.m4a'}],
#    'options': [{'caption': 'OPEN',
#      'actions': [{'name': 'hub:applemusic:deeplink',
#        'type': 'applemusicopen',
#        'uri': 'https://music.apple.com/gb/album/oh-pretty-woman/872478304?i=872478306&mttnagencyid=s2n&mttnsiteid=125115&mttn3pid=Apple-Shazam&mttnsub1=Shazam_web&mttnsub2=5348615A-616D-3235-3830-44754D6D5973&itscg=30201&app=music&itsct=Shazam_web'},
#       {'name': 'hub:applemusic:deeplink',
#        'type': 'uri',
#        'uri': 'https://music.apple.com/gb/album/oh-pretty-woman/872478304?i=872478306&mttnagencyid=s2n&mttnsiteid=125115&mttn3pid=Apple-Shazam&mttnsub1=Shazam_web&mttnsub2=5348615A-616D-3235-3830-44754D6D5973&itscg=30201&app=music&itsct=Shazam_web'}],
#      'beacondata': {'type': 'open', 'providername': 'applemusic'},
#      'image': 'https://images.shazam.com/static/icons/hub/web/v5/overflow-open-option.png',
#      'type': 'open',
#      'listcaption': 'Open in Apple Music',
#      'overflowimage': 'https://images.shazam.com/static/icons/hub/web/v5/applemusic-overflow.png',
#      'colouroverflowimage': False,
#      'providername': 'applemusic'}],
#    'explicit': False,
#    'displayname': 'APPLE MUSIC'},
#   'artists': [{'follow': {'followkey': 'A_1298'},
#     'alias': 'roy-orbison',
#     'id': '1298',
#     'adamid': '198798'}]},
#  {'id': '472830277',
#   'type': 'MUSIC',
#   'layout': '5',
#   'title': 'GOOD TIME',
#   'url': 'https://www.shazam.com/track/472830277/good-time',
#   'apple_music_url': 'https://music.apple.com/gb/album/good-time/1572878538',
#   'subtitle': 'Niko Moon',
#   'images': {'background': 'https://is5-ssl.mzstatic.com/image/thumb/Music125/v4/fb/81/f8/fb81f86a-3610-474a-3e64-3b0bef7a9c6e/pr_source.png/800x800cc.jpg',
#    'coverart': 'https://is1-ssl.mzstatic.com/image/thumb/Music125/v4/95/8a/c8/958ac89a-ae1e-3c6f-f25b-11664f84ae09/886449291632.jpg/400x400cc.jpg',
#    'coverarthq': 'https://is1-ssl.mzstatic.com/image/thumb/Music125/v4/95/8a/c8/958ac89a-ae1e-3c6f-f25b-11664f84ae09/886449291632.jpg/400x400cc.jpg',
#    'joecolor': 'b:f9d100p:020201s:201a05t:332b01q:4c3f04'},
#   'share': {'subject': 'GOOD TIME - Niko Moon',
#    'text': 'I used Shazam to discover GOOD TIME by Niko Moon.',
#    'href': 'https://www.shazam.com/track/472830277/good-time',
#    'image': 'https://is1-ssl.mzstatic.com/image/thumb/Music125/v4/95/8a/c8/958ac89a-ae1e-3c6f-f25b-11664f84ae09/886449291632.jpg/400x400cc.jpg',
#    'twitter': 'I used @Shazam to discover GOOD TIME by Niko Moon.',
#    'html': 'https://www.shazam.com/snippets/email-share/472830277?lang=en&country=GB',
#    'avatar': 'https://is5-ssl.mzstatic.com/image/thumb/Music125/v4/fb/81/f8/fb81f86a-3610-474a-3e64-3b0bef7a9c6e/pr_source.png/800x800cc.jpg',
#    'snapchat': 'https://www.shazam.com/partner/sc/track/472830277'},
#   'hub': {'type': 'APPLEMUSIC',
#    'image': 'https://images.shazam.com/static/icons/hub/web/v5/applemusic.png',
#    'actions': [{'name': 'apple', 'type': 'applemusicplay', 'id': '1572878861'},
#     {'name': 'apple',
#      'type': 'uri',
#      'uri': 'https://audio-ssl.itunes.apple.com/itunes-assets/AudioPreview115/v4/67/e3/f8/67e3f8fa-491c-65d4-bfa8-4476fa239848/mzaf_15060511893376003499.plus.aac.ep.m4a'}],
#    'options': [{'caption': 'OPEN',
#      'actions': [{'name': 'hub:applemusic:deeplink',
#        'type': 'applemusicopen',
#        'uri': 'https://music.apple.com/gb/album/good-time/1572878538?i=1572878861&mttnagencyid=s2n&mttnsiteid=125115&mttn3pid=Apple-Shazam&mttnsub1=Shazam_web&mttnsub2=5348615A-616D-3235-3830-44754D6D5973&itscg=30201&app=music&itsct=Shazam_web'},
#       {'name': 'hub:applemusic:deeplink',
#        'type': 'uri',
#        'uri': 'https://music.apple.com/gb/album/good-time/1572878538?i=1572878861&mttnagencyid=s2n&mttnsiteid=125115&mttn3pid=Apple-Shazam&mttnsub1=Shazam_web&mttnsub2=5348615A-616D-3235-3830-44754D6D5973&itscg=30201&app=music&itsct=Shazam_web'}],
#      'beacondata': {'type': 'open', 'providername': 'applemusic'},
#      'image': 'https://images.shazam.com/static/icons/hub/web/v5/overflow-open-option.png',
#      'type': 'open',
#      'listcaption': 'Open in Apple Music',
#      'overflowimage': 'https://images.shazam.com/static/icons/hub/web/v5/applemusic-overflow.png',
#      'colouroverflowimage': False,
#      'providername': 'applemusic'}],
#    'explicit': False,
#    'displayname': 'APPLE MUSIC'},
#   'artists': [{'follow': {'followkey': 'A_200569225'},
#     'alias': 'niko-moon',
#     'id': '200569225',
#     'adamid': '901457932'}]},
#  {'id': '587778070',
#   'type': 'MUSIC',
#   'layout': '5',
#   'title': 'U Gurl',
#   'url': 'https://www.shazam.com/track/587778070/u-gurl',
#   'apple_music_url': 'https://music.apple.com/gb/album/u-gurl/1595927679',
#   'subtitle': 'Walker Hayes',
#   'images': {'background': 'https://is5-ssl.mzstatic.com/image/thumb/Music125/v4/21/42/4d/21424d42-8255-d95a-eca4-bfceb6c2850c/pr_source.png/800x800cc.jpg',
#    'coverart': 'https://is2-ssl.mzstatic.com/image/thumb/Music126/v4/7d/66/4c/7d664ceb-ae82-0645-4996-daf2f543e7b3/886449714209.jpg/400x400cc.jpg',
#    'coverarthq': 'https://is2-ssl.mzstatic.com/image/thumb/Music126/v4/7d/66/4c/7d664ceb-ae82-0645-4996-daf2f543e7b3/886449714209.jpg/400x400cc.jpg',
#    'joecolor': 'b:1a2529p:a6ceccs:ec9b61t:8aacabq:c28456'},
#   'share': {'subject': 'U Gurl - Walker Hayes',
#    'text': 'I used Shazam to discover U Gurl by Walker Hayes.',
#    'href': 'https://www.shazam.com/track/587778070/u-gurl',
#    'image': 'https://is2-ssl.mzstatic.com/image/thumb/Music126/v4/7d/66/4c/7d664ceb-ae82-0645-4996-daf2f543e7b3/886449714209.jpg/400x400cc.jpg',
#    'twitter': 'I used @Shazam to discover U Gurl by Walker Hayes.',
#    'html': 'https://www.shazam.com/snippets/email-share/587778070?lang=en&country=GB',
#    'avatar': 'https://is5-ssl.mzstatic.com/image/thumb/Music125/v4/21/42/4d/21424d42-8255-d95a-eca4-bfceb6c2850c/pr_source.png/800x800cc.jpg',
#    'snapchat': 'https://www.shazam.com/partner/sc/track/587778070'},
#   'hub': {'type': 'APPLEMUSIC',
#    'image': 'https://images.shazam.com/static/icons/hub/web/v5/applemusic.png',
#    'actions': [{'name': 'apple', 'type': 'applemusicplay', 'id': '1595928066'},
#     {'name': 'apple',
#      'type': 'uri',
#      'uri': 'https://audio-ssl.itunes.apple.com/itunes-assets/AudioPreview116/v4/71/b1/db/71b1db50-03b8-eb00-ba48-71857dbd0e78/mzaf_9362283047939400780.plus.aac.ep.m4a'}],
#    'options': [{'caption': 'OPEN',
#      'actions': [{'name': 'hub:applemusic:deeplink',
#        'type': 'applemusicopen',
#        'uri': 'https://music.apple.com/gb/album/u-gurl/1595927679?i=1595928066&mttnagencyid=s2n&mttnsiteid=125115&mttn3pid=Apple-Shazam&mttnsub1=Shazam_web&mttnsub2=5348615A-616D-3235-3830-44754D6D5973&itscg=30201&app=music&itsct=Shazam_web'},
#       {'name': 'hub:applemusic:deeplink',
#        'type': 'uri',
#        'uri': 'https://music.apple.com/gb/album/u-gurl/1595927679?i=1595928066&mttnagencyid=s2n&mttnsiteid=125115&mttn3pid=Apple-Shazam&mttnsub1=Shazam_web&mttnsub2=5348615A-616D-3235-3830-44754D6D5973&itscg=30201&app=music&itsct=Shazam_web'}],
#      'beacondata': {'type': 'open', 'providername': 'applemusic'},
#      'image': 'https://images.shazam.com/static/icons/hub/web/v5/overflow-open-option.png',
#      'type': 'open',
#      'listcaption': 'Open in Apple Music',
#      'overflowimage': 'https://images.shazam.com/static/icons/hub/web/v5/applemusic-overflow.png',
#      'colouroverflowimage': False,
#      'providername': 'applemusic'}],
#    'explicit': False,
#    'displayname': 'APPLE MUSIC'},
#   'artists': [{'follow': {'followkey': 'A_40817516'},
#     'alias': 'walker-hayes',
#     'id': '40817516',
#     'adamid': '382876655'}]},
#  {'id': '593786772',
#   'type': 'MUSIC',
#   'layout': '5',
#   'title': 'AA',
#   'url': 'https://www.shazam.com/track/593786772/aa',
#   'apple_music_url': 'https://music.apple.com/gb/album/aa/1595927679',
#   'subtitle': 'Walker Hayes',
#   'images': {'background': 'https://is5-ssl.mzstatic.com/image/thumb/Music125/v4/21/42/4d/21424d42-8255-d95a-eca4-bfceb6c2850c/pr_source.png/800x800cc.jpg',
#    'coverart': 'https://is2-ssl.mzstatic.com/image/thumb/Music126/v4/7d/66/4c/7d664ceb-ae82-0645-4996-daf2f543e7b3/886449714209.jpg/400x400cc.jpg',
#    'coverarthq': 'https://is2-ssl.mzstatic.com/image/thumb/Music126/v4/7d/66/4c/7d664ceb-ae82-0645-4996-daf2f543e7b3/886449714209.jpg/400x400cc.jpg',
#    'joecolor': 'b:1a2529p:a6ceccs:ec9b61t:8aacabq:c28456'},
#   'share': {'subject': 'AA - Walker Hayes',
#    'text': 'I used Shazam to discover AA by Walker Hayes.',
#    'href': 'https://www.shazam.com/track/593786772/aa',
#    'image': 'https://is2-ssl.mzstatic.com/image/thumb/Music126/v4/7d/66/4c/7d664ceb-ae82-0645-4996-daf2f543e7b3/886449714209.jpg/400x400cc.jpg',
#    'twitter': 'I used @Shazam to discover AA by Walker Hayes.',
#    'html': 'https://www.shazam.com/snippets/email-share/593786772?lang=en&country=GB',
#    'avatar': 'https://is5-ssl.mzstatic.com/image/thumb/Music125/v4/21/42/4d/21424d42-8255-d95a-eca4-bfceb6c2850c/pr_source.png/800x800cc.jpg',
#    'snapchat': 'https://www.shazam.com/partner/sc/track/593786772'},
#   'hub': {'type': 'APPLEMUSIC',
#    'image': 'https://images.shazam.com/static/icons/hub/web/v5/applemusic.png',
#    'actions': [{'name': 'apple', 'type': 'applemusicplay', 'id': '1595927699'},
#     {'name': 'apple',
#      'type': 'uri',
#      'uri': 'https://audio-ssl.itunes.apple.com/itunes-assets/AudioPreview116/v4/4d/bc/d8/4dbcd84d-7b69-6796-5d3c-1aca840b822c/mzaf_17510208451762926990.plus.aac.ep.m4a'}],
#    'options': [{'caption': 'OPEN',
#      'actions': [{'name': 'hub:applemusic:deeplink',
#        'type': 'applemusicopen',
#        'uri': 'https://music.apple.com/gb/album/aa/1595927679?i=1595927699&mttnagencyid=s2n&mttnsiteid=125115&mttn3pid=Apple-Shazam&mttnsub1=Shazam_web&mttnsub2=5348615A-616D-3235-3830-44754D6D5973&itscg=30201&app=music&itsct=Shazam_web'},
#       {'name': 'hub:applemusic:deeplink',
#        'type': 'uri',
#        'uri': 'https://music.apple.com/gb/album/aa/1595927679?i=1595927699&mttnagencyid=s2n&mttnsiteid=125115&mttn3pid=Apple-Shazam&mttnsub1=Shazam_web&mttnsub2=5348615A-616D-3235-3830-44754D6D5973&itscg=30201&app=music&itsct=Shazam_web'}],
#      'beacondata': {'type': 'open', 'providername': 'applemusic'},
#      'image': 'https://images.shazam.com/static/icons/hub/web/v5/overflow-open-option.png',
#      'type': 'open',
#      'listcaption': 'Open in Apple Music',
#      'overflowimage': 'https://images.shazam.com/static/icons/hub/web/v5/applemusic-overflow.png',
#      'colouroverflowimage': False,
#      'providername': 'applemusic'}],
#    'explicit': False,
#    'displayname': 'APPLE MUSIC'},
#   'artists': [{'follow': {'followkey': 'A_40817516'},
#     'alias': 'walker-hayes',
#     'id': '40817516',
#     'adamid': '382876655'}]},
#  {'id': '270627',
#   'type': 'MUSIC',
#   'layout': '5',
#   'title': '9 To 5',
#   'url': 'https://www.shazam.com/track/270627/9-to-5',
#   'apple_music_url': 'https://music.apple.com/gb/album/9-to-5/255676863',
#   'subtitle': 'Dolly Parton',
#   'images': {'background': 'https://is5-ssl.mzstatic.com/image/thumb/Features115/v4/fb/3f/60/fb3f60b7-5bc5-80aa-bdd3-a4c4339f380c/pr_source.png/800x800cc.jpg',
#    'coverart': 'https://is3-ssl.mzstatic.com/image/thumb/Music/8f/cb/e2/mzi.rnfxjegk.jpg/400x400cc.jpg',
#    'coverarthq': 'https://is3-ssl.mzstatic.com/image/thumb/Music/8f/cb/e2/mzi.rnfxjegk.jpg/400x400cc.jpg',
#    'joecolor': 'b:b59a85p:060401s:080604t:29221cq:2b231d'},
#   'share': {'subject': '9 To 5 - Dolly Parton',
#    'text': 'I used Shazam to discover 9 To 5 by Dolly Parton.',
#    'href': 'https://www.shazam.com/track/270627/9-to-5',
#    'image': 'https://is3-ssl.mzstatic.com/image/thumb/Music/8f/cb/e2/mzi.rnfxjegk.jpg/400x400cc.jpg',
#    'twitter': 'I used @Shazam to discover 9 To 5 by Dolly Parton.',
#    'html': 'https://www.shazam.com/snippets/email-share/270627?lang=en&country=GB',
#    'avatar': 'https://is5-ssl.mzstatic.com/image/thumb/Features115/v4/fb/3f/60/fb3f60b7-5bc5-80aa-bdd3-a4c4339f380c/pr_source.png/800x800cc.jpg',
#    'snapchat': 'https://www.shazam.com/partner/sc/track/270627'},
#   'hub': {'type': 'APPLEMUSIC',
#    'image': 'https://images.shazam.com/static/icons/hub/web/v5/applemusic.png',
#    'actions': [{'name': 'apple', 'type': 'applemusicplay', 'id': '255676909'},
#     {'name': 'apple',
#      'type': 'uri',
#      'uri': 'https://audio-ssl.itunes.apple.com/itunes-assets/AudioPreview115/v4/1b/84/bf/1b84bf90-1a23-e78c-4cf0-44bb886b2d8d/mzaf_2659666354044804093.plus.aac.ep.m4a'}],
#    'options': [{'caption': 'OPEN',
#      'actions': [{'name': 'hub:applemusic:deeplink',
#        'type': 'applemusicopen',
#        'uri': 'https://music.apple.com/gb/album/9-to-5/255676863?i=255676909&mttnagencyid=s2n&mttnsiteid=125115&mttn3pid=Apple-Shazam&mttnsub1=Shazam_web&mttnsub2=5348615A-616D-3235-3830-44754D6D5973&itscg=30201&app=music&itsct=Shazam_web'},
#       {'name': 'hub:applemusic:deeplink',
#        'type': 'uri',
#        'uri': 'https://music.apple.com/gb/album/9-to-5/255676863?i=255676909&mttnagencyid=s2n&mttnsiteid=125115&mttn3pid=Apple-Shazam&mttnsub1=Shazam_web&mttnsub2=5348615A-616D-3235-3830-44754D6D5973&itscg=30201&app=music&itsct=Shazam_web'}],
#      'beacondata': {'type': 'open', 'providername': 'applemusic'},
#      'image': 'https://images.shazam.com/static/icons/hub/web/v5/overflow-open-option.png',
#      'type': 'open',
#      'listcaption': 'Open in Apple Music',
#      'overflowimage': 'https://images.shazam.com/static/icons/hub/web/v5/applemusic-overflow.png',
#      'colouroverflowimage': False,
#      'providername': 'applemusic'}],
#    'explicit': False,
#    'displayname': 'APPLE MUSIC'},
#   'artists': [{'follow': {'followkey': 'A_1605'},
#     'alias': 'dolly-parton',
#     'id': '1605',
#     'adamid': '535066'}]}]

# %%
# Retrieve Track IDs

track_ids=[] # song identifier
titles = [] # song name
subtitles = [] # Main artist and featured artists

for track in range(len(chart_response)):
    track_ids.append(chart_response[track]['id'])
    titles.append(chart_response[track]['title'])
    subtitles.append(chart_response[track]['subtitle'])

print(f"The number of songs retrieved is : {len(track_ids)}")

chart_songs = pd.DataFrame({"Track Name": titles, "Artists": subtitles, 'TrackIDs': track_ids}).set_index('TrackIDs')
chart_songs.head(5)
# Out:
# The number of songs retrieved is : 50
#                                        Track Name          Artists
# TrackIDs
# 595243928  The Cowboy In Me (Yellowstone Edition)       Tim McGraw
# 54640449                         Jingle Bell Rock      Bobby Helms
# 568180108                              Fancy Like     Walker Hayes
# 52815945                                Enchanted     Taylor Swift
# 504707938                    West Texas In My Eye  The Panhandlers

# %%
# Take a look at the data

from collections import Counter

artists_list = list(chart_songs.Artists)
artist_counts = {artist: artists_list.count(artist) for artist in artists_list} #dict with frequency of artist in top chart

artists_df = pd.DataFrame(list(artist_counts.items()),columns = ['Artists','No. Songs in Top Chart']).set_index('Artists')
artists_df.sort_values(by = 'No. Songs in Top Chart', ascending=False, inplace=True) #sort values

# Plot artists frequency in top chart
genre_plot = artists_df.plot.bar(rot=90, width = 1000, height = 600, color = 'yellow', title = f'ARTISTS ON {genre} TOP CHART')
genre_plot
# Out:
# :Bars   [Artists]   (No. Songs in Top Chart)

# %% [markdown]
# ### Search lyrics by TRACK

# %%
# Use 'Track details' endpoint to retrieve lyrics for a single track

track_id = "554591360"

querystring = {"track_id":track_id}
track_details_response = get_lyrics(querystring)
track_details_response
# Out:
# {'id': '554591360',
#  'type': 'MUSIC',
#  'layout': '5',
#  'title': 'Wellerman - Sea Shanty',
#  'url': 'https://www.shazam.com/track/554591360/wellerman-sea-shanty',
#  'apple_music_url': 'https://music.apple.com/gb/album/wellerman-sea-shanty/1550191440',
#  'subtitle': 'Nathan Evans',
#  'images': {'background': 'https://is2-ssl.mzstatic.com/image/thumb/Features114/v4/e8/5b/23/e85b2365-cbe4-72fb-1d5f-fb615b270acf/pr_source.png/800x800cc.jpg',
#   'coverart': 'https://is3-ssl.mzstatic.com/image/thumb/Music125/v4/8b/86/6e/8b866e27-3367-567e-7566-7b9b57ee145c/21UMGIM04866.rgb.jpg/400x400cc.jpg',
#   'coverarthq': 'https://is3-ssl.mzstatic.com/image/thumb/Music125/v4/8b/86/6e/8b866e27-3367-567e-7566-7b9b57ee145c/21UMGIM04866.rgb.jpg/400x400cc.jpg',
#   'joecolor': 'b:000000p:00f0ffs:00d9dat:00bfcbq:00adae'},
#  'share': {'subject': 'Wellerman - Sea Shanty - Nathan Evans',
#   'text': 'I used Shazam to discover Wellerman - Sea Shanty by Nathan Evans.',
#   'href': 'https://www.shazam.com/track/554591360/wellerman-sea-shanty',
#   'image': 'https://is3-ssl.mzstatic.com/image/thumb/Music125/v4/8b/86/6e/8b866e27-3367-567e-7566-7b9b57ee145c/21UMGIM04866.rgb.jpg/400x400cc.jpg',
#   'twitter': 'I used @Shazam to discover Wellerman - Sea Shanty by Nathan Evans.',
#   'html': 'https://www.shazam.com/snippets/email-share/554591360?lang=en&country=GB',
#   'avatar': 'https://is2-ssl.mzstatic.com/image/thumb/Features114/v4/e8/5b/23/e85b2365-cbe4-72fb-1d5f-fb615b270acf/pr_source.png/800x800cc.jpg',
#   'snapchat': 'https://www.shazam.com/partner/sc/track/554591360'},
#  'hub': {'type': 'APPLEMUSIC',
#   'image': 'https://images.shazam.com/static/icons/hub/web/v5/applemusic.png',
#   'actions': [{'name': 'apple', 'type': 'applemusicplay', 'id': '1550191532'},
#    {'name': 'apple',
#     'type': 'uri',
#     'uri': 'https://audio-ssl.itunes.apple.com/itunes-assets/AudioPreview115/v4/53/e6/16/53e61640-c588-ffa8-1787-43b346e5316e/mzaf_3831207977550634271.plus.aac.ep.m4a'}],
#   'options': [{'caption': 'OPEN',
#     'actions': [{'name': 'hub:applemusic:deeplink',
#       'type': 'applemusicopen',
#       'uri': 'https://music.apple.com/gb/album/wellerman-sea-shanty/1550191440?i=1550191532&mttnagencyid=s2n&mttnsiteid=125115&mttn3pid=Apple-Shazam&mttnsub1=Shazam_web&mttnsub2=5348615A-616D-3235-3830-44754D6D5973&itscg=30201&app=music&itsct=Shazam_web'},
#      {'name': 'hub:applemusic:deeplink',
#       'type': 'uri',
#       'uri': 'https://music.apple.com/gb/album/wellerman-sea-shanty/1550191440?i=1550191532&mttnagencyid=s2n&mttnsiteid=125115&mttn3pid=Apple-Shazam&mttnsub1=Shazam_web&mttnsub2=5348615A-616D-3235-3830-44754D6D5973&itscg=30201&app=music&itsct=Shazam_web'}],
#     'beacondata': {'type': 'open', 'providername': 'applemusic'},
#     'image': 'https://images.shazam.com/static/icons/hub/web/v5/overflow-open-option.png',
#     'type': 'open',
#     'listcaption': 'Open in Apple Music',
#     'overflowimage': 'https://images.shazam.com/static/icons/hub/web/v5/applemusic-overflow.png',
#     'colouroverflowimage': False,
#     'providername': 'applemusic'}],
#   'explicit': False,
#   'displayname': 'APPLE MUSIC'},
#  'sections': [{'type': 'SONG',
#    'metapages': [{'image': 'https://is2-ssl.mzstatic.com/image/thumb/Features114/v4/e8/5b/23/e85b2365-cbe4-72fb-1d5f-fb615b270acf/pr_source.png/800x800cc.jpg',
#      'caption': 'Nathan Evans'},
#     {'image': 'https://is3-ssl.mzstatic.com/image/thumb/Music125/v4/8b/86/6e/8b866e27-3367-567e-7566-7b9b57ee145c/21UMGIM04866.rgb.jpg/400x400cc.jpg',
#      'caption': 'Wellerman - Sea Shanty'}],
#    'tabname': 'Song',
#    'metadata': [{'title': 'Album', 'text': 'Wellerman (Sea Shanty) - Single'},
#     {'title': 'Label', 'text': 'Polydor Records'},
#     {'title': 'Released', 'text': '2021'}]},
#   {'type': 'LYRICS',
#    'text': ['There once was a ship that put to sea',
#     'The name of the ship was the Billy of Tea',
#     'The winds blew up, her bow dipped down',
#     'O blow, my bully boys, blow (huh)',
#     '',
#     'Soon may the Wellerman come',
#     'To bring us sugar and tea and rum',
#     "One day, when the tonguin' is done",
#     "We'll take our leave and go",
#     '',
#     'She had not been two weeks from shore',
#     'When down on her, a right whale bore',
#     'The captain called all hands and swore',
#     "He'd take that whale in tow (huh)",
#     '',
#     'Soon may the Wellerman come',
#     'To bring us sugar and tea and rum',
#     "One day, when the tonguin' is done",
#     "We'll take our leave and go",
#     '',
#     'Before the boat had hit the water',
#     "The whale's tail came up and caught her",
#     'All hands to the side, harpooned and fought her',
#     'When she dived down low (huh)',
#     '',
#     'Soon may the Wellerman come',
#     'To bring us sugar and tea and rum',
#     "One day, when the tonguin' is done",
#     "We'll take our leave and go",
#     '',
#     'No line was cut, no whale was freed',
#     "The captain's mind was not on greed",
#     "And he belonged to the whaleman's creed",
#     'She took the ship in tow (huh)',
#     '',
#     'Soon may the Wellerman come',
#     'To bring us sugar and tea and rum',
#     "One day, when the tonguin' is done",
#     "We'll take our leave and go",
#     '',
#     'For 40 days, or even more',
#     'The line went slack, then tight once more',
#     'All boats were lost, there were only four',
#     'But still that whale did go (huh)',
#     '',
#     'Soon may the Wellerman come',
#     'To bring us sugar and tea and rum',
#     "One day, when the tonguin' is done",
#     "We'll take our leave and go",
#     '',
#     "As far as I've heard, the fight's still on",
#     "The line's not cut and the whale's not gone",
#     'The Wellerman makes his regular call',
#     'To encourage the captain, crew, and all (huh)',
#     '',
#     'Soon may the Wellerman come',
#     'To bring us sugar and tea and rum',
#     "One day, when the tonguin' is done",
#     "We'll take our leave and go",
#     '',
#     'Soon may the Wellerman come',
#     'To bring us sugar and tea and rum',
#     "One day, when the tonguin' is done",
#     "We'll take our leave and go"],
#    'footer': 'Lyrics powered by www.musixmatch.com',
#    'tabname': 'Lyrics',
#    'beacondata': {'lyricsid': '25978802',
#     'providername': 'musixmatch',
#     'commontrackid': '119266000'}},
#   {'type': 'VIDEO',
#    'tabname': 'Video',
#    'youtubeurl': 'https://cdn.shazam.com/video/v3/-/GB/web/554591360/youtube/video?q=Nathan+Evans+%22Wellerman+-+Sea+Shanty%22'},
#   {'type': 'ARTIST',
#    'avatar': 'https://is2-ssl.mzstatic.com/image/thumb/Features114/v4/e8/5b/23/e85b2365-cbe4-72fb-1d5f-fb615b270acf/pr_source.png/800x800cc.jpg',
#    'id': '43328183',
#    'name': 'Nathan Evans',
#    'verified': False,
#    'url': 'https://cdn.shazam.com/digest/v1/en/GB/web/artist/43328183/recentpost',
#    'actions': [{'type': 'artistposts', 'id': '43328183'},
#     {'type': 'artist', 'id': '43328183'}],
#    'tabname': 'Artist',
#    'toptracks': {'url': 'https://cdn.shazam.com/shazam/v3/en/GB/web/-/tracks/artisttoptracks_43328183?startFrom=0&pageSize=20&connected='}},
#   {'type': 'RELATED',
#    'url': 'https://cdn.shazam.com/shazam/v3/en/GB/web/-/tracks/track-similarities-id-554591360?startFrom=0&pageSize=20&connected=',
#    'tabname': 'Related'}],
#  'artists': [{'follow': {'followkey': 'A_43328183'},
#    'alias': 'nathan-evans',
#    'id': '43328183',
#    'adamid': '394390215'}],
#  'alias': 'wellerman-sea-shanty',
#  'genres': {'primary': 'Pop'},
#  'album_adam_id': '1550191440',
#  'track_adam_id': '1550191532',
#  'release_date': '21-01-2021'}

# %%
# Retrieve  Lyrics

lyrics = track_details_response['sections'][1]['text']
lyrics
# Out:
# ['There once was a ship that put to sea',
#  'The name of the ship was the Billy of Tea',
#  'The winds blew up, her bow dipped down',
#  'O blow, my bully boys, blow (huh)',
#  '',
#  'Soon may the Wellerman come',
#  'To bring us sugar and tea and rum',
#  "One day, when the tonguin' is done",
#  "We'll take our leave and go",
#  '',
#  'She had not been two weeks from shore',
#  'When down on her, a right whale bore',
#  'The captain called all hands and swore',
#  "He'd take that whale in tow (huh)",
#  '',
#  'Soon may the Wellerman come',
#  'To bring us sugar and tea and rum',
#  "One day, when the tonguin' is done",
#  "We'll take our leave and go",
#  '',
#  'Before the boat had hit the water',
#  "The whale's tail came up and caught her",
#  'All hands to the side, harpooned and fought her',
#  'When she dived down low (huh)',
#  '',
#  'Soon may the Wellerman come',
#  'To bring us sugar and tea and rum',
#  "One day, when the tonguin' is done",
#  "We'll take our leave and go",
#  '',
#  'No line was cut, no whale was freed',
#  "The captain's mind was not on greed",
#  "And he belonged to the whaleman's creed",
#  'She took the ship in tow (huh)',
#  '',
#  'Soon may the Wellerman come',
#  'To bring us sugar and tea and rum',
#  "One day, when the tonguin' is done",
#  "We'll take our leave and go",
#  '',
#  'For 40 days, or even more',
#  'The line went slack, then tight once more',
#  'All boats were lost, there were only four',
#  'But still that whale did go (huh)',
#  '',
#  'Soon may the Wellerman come',
#  'To bring us sugar and tea and rum',
#  "One day, when the tonguin' is done",
#  "We'll take our leave and go",
#  '',
#  "As far as I've heard, the fight's still on",
#  "The line's not cut and the whale's not gone",
#  'The Wellerman makes his regular call',
#  'To encourage the captain, crew, and all (huh)',
#  '',
#  'Soon may the Wellerman come',
#  'To bring us sugar and tea and rum',
#  "One day, when the tonguin' is done",
#  "We'll take our leave and go",
#  '',
#  'Soon may the Wellerman come',
#  'To bring us sugar and tea and rum',
#  "One day, when the tonguin' is done",
#  "We'll take our leave and go"]

# %% [markdown]
# ### Generate Lyrics DataFrame

# %% [markdown]
# # Export lyrics to a single .txt file
